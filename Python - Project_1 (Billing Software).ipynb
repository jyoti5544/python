# %%
from tkinter import *
import os
from PIL import ImageTk, Image
from tkinter import ttk
from tkinter import messagebox
top = Tk()
top.geometry('900x600')
top.config(bg='light gray')
top.title("Billing Software")
path = 'C:\\Users\\laptop\\Pictures\\Saved Pictures\\JPG File (.jpg)'

L = Label(top, text='BILLING SOFTWARE BY JYOTI', bg='light gray', fg='red', font=('arial 30 bold'))
L.place(x=200, y=40)
L6 = Label(top, text='Customer', bg='light gray', fg='red', font=('arial 12 bold'))
L6.place(x=50, y=90)

L2 = Label(top, text='Mobile No:', bg='light gray', fg='black', font=('arial 13 bold'))
L2.place(x=100, y=130)
e1 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e1.place(x=300, y=130)
L3 = Label(top, text='Customer Name:', bg='light gray', fg='black', font=('arial 13 bold'))
L3.place(x=100, y=180)
e2 = Entry(top, font=('arial 20 bold'), fg='blue', bg="light gray")
e2.place(x=300, y=180)
L4 = Label(top, text='Email:', bg='light gray', fg='black', font=('arial 13 bold'))
L4.place(x=100, y=230)
e3 = Entry(top, font=('arial 20 bold'), show="*", fg='blue', bg="light gray")
e3.place(x=300, y=230)

L7 = Label(top, text='Product', bg='light gray', fg='red', font=('arial 12 bold'))
L7.place(x=50, y=290)

L8 = Label(top, text='Select Categories:', bg='light gray', fg='black', font=('arial 13 bold'))
L8.place(x=100, y=320)
e4 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e4.place(x=300, y=320)

L9 = Label(top, text='Sub Categories:', bg='light gray', fg='black', font=('arial 13 bold'))
L9.place(x=100, y=370)
e5 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e5.place(x=300, y=370)

L10 = Label(top, text='Product Name:', bg='light gray', fg='black', font=('arial 13 bold'))
L10.place(x=100, y=420)
e6 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e6.place(x=300, y=420)

L11 = Label(top, text='Bill Counter', bg='light gray', fg='red', font=('arial 12 bold'))
L11.place(x=50, y=500)

L12 = Label(top, text='Sub Total:', bg='light gray', fg='black', font=('arial 13 bold'))
L12.place(x=100, y=540)
e7 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e7.place(x=300, y=540)

L12 = Label(top, text='Govt Tax:', bg='light gray', fg='black', font=('arial 13 bold'))
L12.place(x=100, y=590)
e8 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e8.place(x=300, y=590)

L13 = Label(top, text='Total:', bg='light gray', fg='black', font=('arial 13 bold'))
L13.place(x=100, y=640)
e6 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e6.place(x=300, y=640)

L14 = Label(top, text='Price:', bg='light gray', fg='black', font=('arial 13 bold'))
L14.place(x=650, y=320)
e9 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e9.place(x=730, y=320)

L15 = Label(top, text='Quantity:', bg='light gray', fg='black', font=('arial 13 bold'))
L15.place(x=650, y=370)
e10 = Entry(top, font=('arial 20 bold'), bg="light gray", fg='blue')
e10.place(x=730, y=370)




b = Button(top, text="Add To Cart", bg="orange", fg='black', font=("aerial 14 bold"))
b.place(x=800, y=420)

b1 = Button(top, text="Generate Bill", bg='orange', font=('aerial 14 bold'), command='Delete')
b1.place(x=650, y=590)
b2 = Button(top, text="Save Bill", bg='orange', font=('aerial 14 bold'), command='Delete')
b2.place(x=780, y=590)
b3 = Button(top, text="Print", bg='orange', font=('aerial 14 bold'), command='Delete')
b3.place(x=870, y=590)
b4 = Button(top, text="Clear", bg='orange', font=('aerial 14 bold'), command='Delete')
b4.place(x=930, y=590)
b5 = Button(top, text="Exit", bg='orange', font=('aerial 14 bold'), command='Delete')
b5.place(x=990, y=590)
top.mainloop()
